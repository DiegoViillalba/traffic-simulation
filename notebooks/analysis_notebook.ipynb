# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
logging.basicConfig(level=logging.WARNING)

# %%
from analysis import (
    load_config,
    load_results,
    get_density
)

# %%
CONFIG_PATH = "/Users/diegovillaba/Code/traffic-simulation/configs/tesis_zuriel.yaml"
DATA_PATH = "/Users/diegovillaba/Code/traffic-simulation/results/tesis_zuriel_20260430_120844"

# %%
cfg = load_config(CONFIG_PATH)
data,_ = load_results(DATA_PATH)
# Out:
# 2026-04-30 13:46:26,519 - INFO - Loading results from: /Users/diegovillaba/Code/traffic-simulation/results/tesis_zuriel_20260430_120844
# 2026-04-30 13:46:26,523 - INFO - Simulation Summary:
# 2026-04-30 13:46:26,523 - INFO - tiempo_simulado_s: 1000.0
# 2026-04-30 13:46:26,524 - INFO - hilos: 1
# 2026-04-30 13:46:26,524 - INFO - pasos_calentamiento: 0
# 2026-04-30 13:46:26,525 - INFO - config_usado: configs/tesis_zuriel.yaml
# 2026-04-30 13:46:26,525 - INFO - pasos: 10000
# 2026-04-30 13:46:26,525 - INFO - animacion: False
# 2026-04-30 13:46:26,526 - INFO - n_vehiculos: 100
# 2026-04-30 13:46:26,526 - INFO - tiempo_computo_s: 1126.733
# 2026-04-30 13:46:26,526 - INFO - experimento: tesis_zuriel
# 2026-04-30 13:46:26,527 - INFO - timestamp: 20260430_120844
# 2026-04-30 13:46:26,527 - INFO - grilla_espacial: True
# 2026-04-30 13:46:26,527 - INFO - benchmarks: {}
# 2026-04-30 13:46:26,535 - INFO - Loaded 10000 rows from CSV

# %%
data_no_grid , _ = load_results("/Users/diegovillaba/Code/traffic-simulation/results/tesis_zuriel_20260430_125659")
data_grid,_ = load_results("/Users/diegovillaba/Code/traffic-simulation/results/tesis_zuriel_20260430_122850")
# Out:
# 2026-04-30 13:46:38,431 - INFO - Loading results from: /Users/diegovillaba/Code/traffic-simulation/results/tesis_zuriel_20260430_125659
# 2026-04-30 13:46:38,433 - INFO - Simulation Summary:
# 2026-04-30 13:46:38,433 - INFO - tiempo_simulado_s: 100.0
# 2026-04-30 13:46:38,433 - INFO - hilos: 1
# 2026-04-30 13:46:38,434 - INFO - pasos_calentamiento: 0
# 2026-04-30 13:46:38,434 - INFO - config_usado: configs/tesis_zuriel.yaml
# 2026-04-30 13:46:38,434 - INFO - pasos: 1000
# 2026-04-30 13:46:38,435 - INFO - animacion: False
# 2026-04-30 13:46:38,435 - INFO - n_vehiculos: 100
# 2026-04-30 13:46:38,436 - INFO - tiempo_computo_s: 111.244
# 2026-04-30 13:46:38,436 - INFO - experimento: tesis_zuriel
# 2026-04-30 13:46:38,436 - INFO - timestamp: 20260430_125659
# 2026-04-30 13:46:38,437 - INFO - grilla_espacial: False
# 2026-04-30 13:46:38,437 - INFO - benchmarks: {}
# 2026-04-30 13:46:38,440 - INFO - Loaded 1000 rows from CSV
# 2026-04-30 13:46:38,440 - INFO - Loading results from: /Users/diegovillaba/Code/traffic-simulation/results/tesis_zuriel_20260430_122850
# 2026-04-30 13:46:38,442 - INFO - Simulation Summary:
# 2026-04-30 13:46:38,442 - INFO - tiempo_simulado_s: 100.0
# 2026-04-30 13:46:38,442 - INFO - hilos: 1
# 2026-04-30 13:46:38,443 - INFO - pasos_calentamiento: 0
# 2026-04-30 13:46:38,443 - INFO - config_usado: configs/tesis_zuriel.yaml
# 2026-04-30 13:46:38,444 - INFO - pasos: 1000
# 2026-04-30 13:46:38,444 - INFO - animacion: False
# 2026-04-30 13:46:38,444 - INFO - n_vehiculos: 100
# 2026-04-30 13:46:38,445 - INFO - tiempo_computo_s: 117.873
# 2026-04-30 13:46:38,446 - INFO - experimento: tesis_zuriel
# 2026-04-30 13:46:38,447 - INFO - timestamp: 20260430_122850
# 2026-04-30 13:46:38,447 - INFO - grilla_espacial: True
# 2026-04-30 13:46:38,448 - INFO - benchmarks: {}
# 2026-04-30 13:46:38,450 - INFO - Loaded 1000 rows from CSV

# %%
density_sim = get_density(cfg)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(data["tiempo"], data["velocidad_promedio"], label=f"Velocidad Promedio (densidad = {density_sim:.2f})")
plt.plot(data_no_grid["tiempo"], data_no_grid["velocidad_promedio"], label="Velocidad Promedio (Sin Grid)", linestyle="--")
plt.plot(data_grid["tiempo"], data_grid["velocidad_promedio"], label="Velocidad Promedio (Con Grid)", linestyle=":")


plt.xlabel("Tiempo (s)")
plt.ylabel("Velocidad Promedio (unidades/s)")
plt.title("Velocidad Promedio vs Tiempo")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Comparisson of results

# %%
data_sim_2,_ = load_results("/Users/diegovillaba/Code/traffic-simulation/results/tesis_zuriel_20260430_134957")
cfg_2 = load_config("/Users/diegovillaba/Code/traffic-simulation/configs/tesis_zuriel_02.yaml")
density_sim_2 = get_density(cfg_2)
# Out:
# 2026-04-30 13:55:33,370 - INFO - Loading results from: /Users/diegovillaba/Code/traffic-simulation/results/tesis_zuriel_20260430_134957
# 2026-04-30 13:55:33,375 - INFO - Simulation Summary:
# 2026-04-30 13:55:33,375 - INFO - tiempo_simulado_s: 1000.0
# 2026-04-30 13:55:33,376 - INFO - hilos: 1
# 2026-04-30 13:55:33,376 - INFO - pasos_calentamiento: 0
# 2026-04-30 13:55:33,376 - INFO - config_usado: configs/tesis_zuriel_02.yaml
# 2026-04-30 13:55:33,376 - INFO - pasos: 10000
# 2026-04-30 13:55:33,377 - INFO - animacion: False
# 2026-04-30 13:55:33,377 - INFO - n_vehiculos: 47
# 2026-04-30 13:55:33,377 - INFO - tiempo_computo_s: 276.286
# 2026-04-30 13:55:33,377 - INFO - experimento: tesis_zuriel
# 2026-04-30 13:55:33,377 - INFO - timestamp: 20260430_134957
# 2026-04-30 13:55:33,377 - INFO - grilla_espacial: True
# 2026-04-30 13:55:33,378 - INFO - benchmarks: {}
# 2026-04-30 13:55:33,473 - INFO - Loaded 10000 rows from CSV

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(data["tiempo"], data["velocidad_promedio"], label=f"Density ({density_sim:.2f} )")
plt.plot(data_sim_2["tiempo"], data_sim_2["velocidad_promedio"], label=f"Density ({density_sim_2:.2f} )", linestyle="--")


plt.xlabel("Tiempo (s)")
plt.ylabel("Velocidad Promedio (unidades/s)")
plt.title("Velocidad Promedio vs Tiempo")
plt.legend()
plt.grid()
plt.show()
